# %% [markdown]
# #**Apuntes - Semana 3** - *Continuacion Semana 2*
#
#
# *Ángel Gabriel Valenzuela Guerrero*
# ---
# ## *Teoría de conjuntos.*
# Rama fundamental de la matemática que estudia las propiedades y relaciones de los conjuntos, que son colecciones bien definidas de objetos, llamados elementos.
#
# ---
#
# ## *Conjunto.*
# Una colección de elementos claramente definidos.
# Ejemplo:
#
# **𝐴
# =
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# }**
#
#
# -Aquí,
# **𝐴**
#   es un conjunto cuyos elementos son
# **1
# ,
# 2
# ,
# 3
# ,
# 4.**
#
# Cada objeto dentro de un conjunto se llama elemento, denotado por el símbolo
# **∈**.
# Ejemplo:
# **2
# ∈
# 𝐴**
# significa que
# **2**
#  es un elemento del conjunto
# **𝐴**.
#
# ---
# ## *Diagrama de Benn.*
# El diagrama de Venn es una representación gráfica que muestra las relaciones entre conjuntos. Es útil para visualizar intersecciones, uniones, diferencias y otras operaciones entre conjuntos.
#
# ---
# ## *Población*.
#
#  La población es el conjunto completo de elementos o individuos que cumplen con ciertas características que utilizaremos para nuestro análisis estadístico.
#
# el Universo representa una población.
#
# Se componen de:
#
# - Conjuntos
# - Subconjuntos
#
# - *Representados por Axiomas. *
#
# **Un conjunto B se genera mediante un Axioma excluyente o Correlativo de un conjunto A.**
#
# - Correlación
# - Exclusión
#
# **Población finita**. Conjunto con fin aparente.
#
# **Población infinita**. Conjunto sin fin aparente.
#
# ---
#
# ## *Muestra.*
#
# La muestra es el conjunto o subconjunto representativo que es seleccionado para el análisis estadístico de una población.
#
# *-Debe contener todas las características de una población-*
#
# - Representativa
# - Tamaño demostrativo (n)
# - Diversidad de Datos
#
# **“Parámetro”. V**alor numérico que describa una característica de una población.
#
# **”Valor estadístico”.** Valor calculado a partir de una muestra de una población. ****
#
# ¿Cómo elaborar una muestra?
#
# ---
#
# ## *Muestreo.*
#
# Técnica para representar  a una población.
#
# ### *Muestreo Aleatorio Probabilístico.*
#
# Cada elemento debe tener la misma probabilidad de ser seleccionado para la muestra.
#
# **-Métodos de Estratificación-**
#
# - **Aleatorio Sistemático.** Tener un sistema aleatorio para la elección de los datos
# - **Aleatorio Simple**. números al azar utilizando métodos de programación para simular la aleatoriedad.
# - **Estratificación**. Dividir la Población en conjunto a segmentos (Estratos) seleccionados proporcionalmente.
# - **Conglomerado**. Dividir la población en grupos, y se seleccionan varios grupos para realizar la muestra.
#
# ### *Muestreo No Probabilístico.*
#
# Seleccionado según los criterios no aleatorios realizados según el experimentador.
#
# **-Métodos de Estratificación-**
#
# - **Por Conveniencia.** Tomar datos convenientes para realizar la muestra.
# - **Por juicio.** Basados por la experiencia de un senior.
# - **Por Cuotas.** Cuotas con proporciones especificas.
# - **Snow Ball.** El primer datos seleccionado elige los siguientes.
#
#
# ---

# %% [markdown]
# ##Configuracion del ambiente de trabajo

# %%
import pandas as pd
data = pd.read_csv('/content/SoftwareProject_DataSet.csv')

# %% [markdown]
# ##Verificacion de contendo de DataSet
# ---

# %%
data.head(n=10)
# Out:
#                         Proyecto    Módulo       Desarrollador  \
# 0      Smith, Torres and Flowers      long       Patricia Ford
# 1                Jordan and Sons      lose      Melissa Briggs
# 2     Madden, Jackson and Keller  thousand    Alexander Spence
# 3                    Evans Group     table      Michael Porter
# 4                    Pearson LLC     light      Andrew Gregory
# 5     Williams, Mckee and Kelley  audience        Jane Donovan
# 6  Harrison, Carroll and Barnett  attorney  Michael Fitzgerald
# 7                     Bean-Payne    decide    Jessica Williams
# 8           Fitzpatrick and Sons     small        Steven Allen
# 9                     Ray-Arnold      term       Deborah Davis
#
#    Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0              4227              39                           375
# 1              6124              37                           132
# 2               588              30                           441
# ...

# %% [markdown]
# ##Obtener el tamaño de la poblacion
# ---

# %%
data.head(n=10)
# Out:
#                         Proyecto    Módulo       Desarrollador  \
# 0      Smith, Torres and Flowers      long       Patricia Ford
# 1                Jordan and Sons      lose      Melissa Briggs
# 2     Madden, Jackson and Keller  thousand    Alexander Spence
# 3                    Evans Group     table      Michael Porter
# 4                    Pearson LLC     light      Andrew Gregory
# 5     Williams, Mckee and Kelley  audience        Jane Donovan
# 6  Harrison, Carroll and Barnett  attorney  Michael Fitzgerald
# 7                     Bean-Payne    decide    Jessica Williams
# 8           Fitzpatrick and Sons     small        Steven Allen
# 9                     Ray-Arnold      term       Deborah Davis
#
#    Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0              4227              39                           375
# 1              6124              37                           132
# 2               588              30                           441
# ...

# %%
population_size = len(data)
print ("El tamaño de la poblacion es: " , population_size)
#len es una funcion que nos devuelve la longitud de un valor.
# Out:
# El tamaño de la poblacion es:  10000

# %% [markdown]
# # Muestreo - Ejemplo de clase
# ### Creacion de una muestra aleatoria simple de 50 registros.

# %%
sample_size = 50
sample = data.sample(n= sample_size,random_state=77)

# %% [markdown]
# ### Revision de la Muestra.

# %%
sample_size= len(sample)
print (sample_size)
# Out:
# 50

# %% [markdown]
# # Seleccion sistematica de la  muestra.

# %% [markdown]
# ####Definicion del intervalo K (tamaño de la poblacion / tamaño de la muestra)

# %%
sample_size = 100
interval_k = population_size//sample_size

# %% [markdown]
# ###Seleccion de Muestra sistematica

# %%
systematic_sample = data.iloc[::interval_k]

# %%
print ("Muestra obtenida por muestreo sistematico:")
display(systematic_sample)
# Out:
# Muestra obtenida por muestreo sistematico:
#                            Proyecto      Módulo        Desarrollador  \
# 0         Smith, Torres and Flowers        long        Patricia Ford
# 100                   Bell and Sons      forget      Katie Carpenter
# 200         Hughes, West and Austin     purpose      Kristina Palmer
# 300                 Howard and Sons    thousand      Elizabeth Lopez
# 400                    Lawrence PLC     surface          Paula Smith
# ...                             ...         ...                  ...
# 9500  Adams, Simmons and Richardson  understand      Richard Johnson
# 9600                 Fuller-Johnson  Republican   Julia Matthews DDS
# 9700                 Robinson Group    consider        Caleb Skinner
# 9800        Lopez, Miller and Myers      growth  Christopher Salazar
# 9900               Chapman-Phillips      detail          Jeremy Ruiz
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# ...

# %% [markdown]
# ### Agrupacion de datos y subpoblaciones
# Dividir la poblacion por un factor

# %%
grouped_by_dev_lenguage = data.groupby("Idioma de programación")
grouped_by_dev_lenguage.head ()
# Out:
#                          Proyecto       Módulo          Desarrollador  \
# 0       Smith, Torres and Flowers         long          Patricia Ford
# 1                 Jordan and Sons         lose         Melissa Briggs
# 2      Madden, Jackson and Keller     thousand       Alexander Spence
# 3                     Evans Group        table         Michael Porter
# 4                     Pearson LLC        light         Andrew Gregory
# 5      Williams, Mckee and Kelley     audience           Jane Donovan
# 6   Harrison, Carroll and Barnett     attorney     Michael Fitzgerald
# 7                      Bean-Payne       decide       Jessica Williams
# 9                      Ray-Arnold         term          Deborah Davis
# 10                     Palmer PLC          age        Zachary Johnson
# 12                Valentine-Myers       ground  Mr. Alvin Gardner DVM
# 13     Armstrong, Hudson and Dunn      medical         Brandon Martin
# ...

# %%
gruop_analysis = grouped_by_dev_lenguage[['Líneas de código','Número de bugs']].mean()
print("analisis por lenguaje de programacion")
display(gruop_analysis)
# Out:
# analisis por lenguaje de programacion
#                         Líneas de código  Número de bugs
# Idioma de programación
# Java                         5046.673913       24.454193
# Javascript                   5038.137720       25.222722
# Kotlin                       5018.528842       25.106091
# Python                       5128.660528       25.423139

# %% [markdown]
# #Muestreo - Asignacion 2 (Semana 2)

# %% [markdown]
# - Se establece el tamaño de una segunda muestra

# %%
sample_size2= 200
print (sample_size2)
# Out:
# 200

# %% [markdown]
# ### Seleccion sistematica de la muestra

# %% [markdown]
# - Definicion del intervalo K (Poblacion / Muestra)

# %%
Interval_K2 = population_size//sample_size2

# %% [markdown]
# - Seleccion de la Muestra sistematica

# %%
systematic_sample2 = data.iloc[::Interval_K2]

# %% [markdown]
# ###Agrupacion de Datos y Subconjuntos

# %% [markdown]
# - Dividir la poblacion mediante un factor.

# %%
grouped_by_Time = data.groupby("Tiempo de desarrollo (horas)")
grouped_by_Time.head ()
# Out:
#                         Proyecto       Módulo     Desarrollador  \
# 0      Smith, Torres and Flowers         long     Patricia Ford
# 1                Jordan and Sons         lose    Melissa Briggs
# 2     Madden, Jackson and Keller     thousand  Alexander Spence
# 3                    Evans Group        table    Michael Porter
# 4                    Pearson LLC        light    Andrew Gregory
# ...                          ...          ...               ...
# 5315      Day, Barton and Norman         keep       Shelly Shah
# 5397     Downs, Nichols and Hart  participant      Jared Powell
# 5487                 Johnson PLC         fast  Darrell Lawrence
# 5785                Diaz-Hammond   especially         Mark Berg
# 6502                 Edwards PLC       camera    Logan Clements
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0                 4227              39                           375
# ...

# %% [markdown]
# - Creacion de subconjuntos.

# %%
gruop_analysis2 = grouped_by_Time[["Costo (USD)","Satisfacción del cliente"]].mean()
print("Analisis de la problacion por Tiempo de desarrolo en Horas:")
display(gruop_analysis2)
# Out:
# Analisis de la problacion por Tiempo de desarrolo en Horas:
#                                Costo (USD)  Satisfacción del cliente
# Tiempo de desarrollo (horas)
# 10                            46556.357143                  2.500000
# 11                            52343.625000                  2.875000
# 12                            61728.000000                  2.708333
# 13                            37226.947368                  3.263158
# 14                            55967.640000                  3.080000
# ...                                    ...                       ...
# 496                           56638.411765                  2.764706
# 497                           51559.260870                  3.043478
# 498                           61243.200000                  2.266667
# 499                           54286.928571                  2.500000
# 500                           42152.315789                  3.263158
#
# [491 rows x 2 columns]

# %% [markdown]
# #APUNTES - Semana 3
# 24/01/2025
#
#
# Angel Gabriel Valenzuela Guerrero

# %% [markdown]
# ##Creacion de Muestras Estratificadas por "Tipo de proyecto".

# %%
grouped_by_project_type = data.groupby("Tipo de proyecto")
grouped_by_Time.head()
# Out:
#                         Proyecto       Módulo     Desarrollador  \
# 0      Smith, Torres and Flowers         long     Patricia Ford
# 1                Jordan and Sons         lose    Melissa Briggs
# 2     Madden, Jackson and Keller     thousand  Alexander Spence
# 3                    Evans Group        table    Michael Porter
# 4                    Pearson LLC        light    Andrew Gregory
# ...                          ...          ...               ...
# 5315      Day, Barton and Norman         keep       Shelly Shah
# 5397     Downs, Nichols and Hart  participant      Jared Powell
# 5487                 Johnson PLC         fast  Darrell Lawrence
# 5785                Diaz-Hammond   especially         Mark Berg
# 6502                 Edwards PLC       camera    Logan Clements
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0                 4227              39                           375
# ...

# %%
stratified_sample = grouped_by_project_type.sample(n=100,random_state=42)
print("Muestra estratificada")
display(stratified_sample)
# Out:
# Muestra estratificada
#                          Proyecto    Módulo      Desarrollador  \
# 3275                    Green Inc      ever        Erik Finley
# 6914                 Smith-Miller  approach     Tony Carpenter
# 2315           Hamilton-Gutierrez    window    Jacqueline Neal
# 8422                  Stewart LLC      hair  Michael Hernandez
# 546   Brewer, Sanders and Wilkins       see       Devon Flores
# ...                           ...       ...                ...
# 802                 Mata-Peterson    health      Chris Salazar
# 1340    Mejia, Carrillo and Brown      than     Janet Ferguson
# 3320                    Gomez PLC     young      Ryan Mcdonald
# 2545  Johnson, Peters and Robbins   society    Jennifer Wright
# 9474                Johnson Group     today       Brian Cooper
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 3275              5753              42                            36
# ...

# %% [markdown]
# ---
#
# ## Muestreo por conveniencia

# %%
convenience_sample = data.head(50)

print ("Sample of the first rows of the plataform")
display(convenience_sample)
# Out:
# Sample of the first rows of the plataform
#                          Proyecto       Módulo          Desarrollador  \
# 0       Smith, Torres and Flowers         long          Patricia Ford
# 1                 Jordan and Sons         lose         Melissa Briggs
# 2      Madden, Jackson and Keller     thousand       Alexander Spence
# 3                     Evans Group        table         Michael Porter
# 4                     Pearson LLC        light         Andrew Gregory
# 5      Williams, Mckee and Kelley     audience           Jane Donovan
# 6   Harrison, Carroll and Barnett     attorney     Michael Fitzgerald
# 7                      Bean-Payne       decide       Jessica Williams
# 8            Fitzpatrick and Sons        small           Steven Allen
# 9                      Ray-Arnold         term          Deborah Davis
# 10                     Palmer PLC          age        Zachary Johnson
# 11                   Anderson Inc         girl     Vanessa Richardson
# ...

# %% [markdown]
# ##Comparacion en los metodos de muestreo

# %%
methods_comparison = pd.DataFrame({
    "Poblacion General: ": data['Tiempo de desarrollo (horas)'].mean(),
    "Aleatorio Simple: ": sample['Tiempo de desarrollo (horas)'].mean(),
    "Aleatorio Sistematico: ": systematic_sample['Tiempo de desarrollo (horas)'].mean(),
    "Aleatoria estratificada: ": stratified_sample['Tiempo de desarrollo (horas)'].mean(),
    "No Aleatorio por Conveniencia: ": convenience_sample['Tiempo de desarrollo (horas)'].mean(),

                                   }, index = ["Media de Horas de desarrollo"])

print("Comparacion de metodos")
display(methods_comparison)
# Out:
# Comparacion de metodos
#                               Poblacion General:   Aleatorio Simple:   \
# Media de Horas de desarrollo             254.7021              263.58
#
#                               Aleatorio Sistematico:   \
# Media de Horas de desarrollo                   257.51
#
#                               Aleatoria estratificada:   \
# Media de Horas de desarrollo                      258.0
#
#                               No Aleatorio por Conveniencia:
# Media de Horas de desarrollo                           267.82

# %% [markdown]
# # Ejercicio - Muestra Estratificada
# Muestra = 20
#
# Agrupacion por Lenguaje de programacion

# %%
grouped_by_platform = data.groupby("Plataforma")
grouped_by_platform.head()
# Out:
#                       Proyecto       Módulo       Desarrollador  \
# 0    Smith, Torres and Flowers         long       Patricia Ford
# 1              Jordan and Sons         lose      Melissa Briggs
# 2   Madden, Jackson and Keller     thousand    Alexander Spence
# 3                  Evans Group        table      Michael Porter
# 4                  Pearson LLC        light      Andrew Gregory
# 5   Williams, Mckee and Kelley     audience        Jane Donovan
# 9                   Ray-Arnold         term       Deborah Davis
# 13  Armstrong, Hudson and Dunn      medical      Brandon Martin
# 16                  Watson Inc         kind       Scott Mcmahon
# 17                   Allen Ltd  performance         Renee Chung
# 18            Simmons and Sons          end  Kathleen Schneider
# 20                 Vaughan Inc     describe       Joseph Sutton
# 21                 Moore Group         vote        Ashley Smith
# 23              Jackson-Palmer         west     James Underwood
# ...

# %%
stratifiend_sample= grouped_by_platform.sample(n=5,random_state=54)
print("Muestra estratificada Por plataforma")
stratifiend_sample_sprt= stratifiend_sample.sort_values(by="Plataforma")
display (stratifiend_sample)
# Out:
# Muestra estratificada Por plataforma
#                        Proyecto     Módulo      Desarrollador  \
# 6334                Fisher-Bass       fall   Ms. Lisa Holt MD
# 6932                Bernard PLC      reach         Jon Torres
# 6878              Kennedy Group        now        John Mercer
# 903                  Bond-Gomez      place        Max Coleman
# 21                  Moore Group       vote       Ashley Smith
# 6555              Gilbert-Watts        war     Wendy Johnston
# 2648                 Butler Ltd     minute        Jaime Smith
# 1900                  Ayala Inc   politics        Kelly Curry
# 96                Watts-Solomon      state     Priscilla Bush
# 7790                 Bryant Ltd      large      Lisa Guerrero
# 339            Campbell-Padilla  according     Lindsay Decker
# 1775                   Gray PLC       view  Timothy Rodriguez
# 748   Osborne, Smith and Howell       room    Adriana Jackson
# ...

# %% [markdown]
# ##Ejercicio - Adicional prorpio

# %%
Grouped_by_Fase = data.groupby("Fase del proyecto")
Grouped_by_Fase.head()
startified_sample_Fase = Grouped_by_Fase.sample(n=5,random_state=54)
startified_sample_Fase.head()
print("Muestra estratificada por Fase del proyecto")
display(startified_sample_Fase)
# Out:
# Muestra estratificada por Fase del proyecto
#                            Proyecto       Módulo       Desarrollador  \
# 1426       Quinn, Flores and Butler       debate        Nancy Jacobs
# 2459   Richards, Vance and Sullivan          ago        Jose Aguilar
# 2840                Christian Group        today      Douglas Wright
# 4142     Santiago, Hunt and Ellison          hit      Jeffrey Hoover
# 2635     Jones, Anderson and Nelson     attorney        Janice Hines
# 8708                  Nelson-Thomas         mind       Sylvia Miller
# 4728                 King-Patterson  interesting       Mandy Simmons
# 5573      Rowland, Barton and David         ball     Lawrence Weaver
# 1273          Woods, Ford and Brown      between    Patricia Ramirez
# 986                       Olson Inc        might       Jason Holland
# 1087                 Thomas-Perkins        clear  Jonathan Wilkinson
# 8259                    Pitts-Smith      special           Angel Ray
# ...
